# %% [markdown]
# ## Importación modulos y datos

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/conchillas_orig.csv", low_memory=False)

# %% [markdown]
# ## Exploración datos

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Lote       1212 non-null   int64
#  1   Individuo  1212 non-null   int64
#  2   AE         1212 non-null   float64
#  3   LE         1212 non-null   float64
#  4   AT         1212 non-null   float64
#  5   LT         1212 non-null   float64
#  6   AA         1212 non-null   float64
#  7   LA         1212 non-null   float64
#  8   NV         1212 non-null   float64
#  9   Morfotipo  1212 non-null   object
#  10  Labio      1212 non-null   int64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 104.3+ KB

# %%
data.head()
# Out:
#    Lote  Individuo    AE    LE     AT     LT    AA    LA    NV Morfotipo  \
# 0    96          5  6.18  1.83  13.57  10.00  8.10  6.04  5.15        LU
# 1    96          5  6.16  1.83  13.66  10.08  8.16  6.13  5.12        LU
# 2    96          5  6.14  1.81  13.61  10.01  8.20  6.14  5.10        LU
# 3    96          5  6.18  1.82  13.85  10.07  8.16  6.14  5.09        LU
# 4    96          6  6.58  2.16  11.69   9.10  6.56  4.92  5.49        LU
#
#    Labio
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0

# %%
data["Morfotipo"].astype('category')
# Out:
# 0       LU
# 1       LU
# 2       LU
# 3       LU
# 4       LU
#         ..
# 1207    LU
# 1208    LB
# 1209    LB
# 1210    LB
# 1211    LB
# Name: Morfotipo, Length: 1212, dtype: category
# Categories (3, object): ['DU', 'LB', 'LU']

# %%
data.Morfotipo.value_counts()
# Out:
# LU    1040
# LB     164
# DU       8
# Name: Morfotipo, dtype: int64

# %%
data.iloc[:,2:-1].describe()
# Out:
#                 AE           LE           AT           LT           AA  \
# count  1212.000000  1212.000000  1212.000000  1212.000000  1212.000000
# mean      6.121980     1.753333    13.009167     9.633936     7.578465
# std       0.976585     0.361939     1.931606     1.397661     1.215578
# min       3.180000     0.690000     7.920000     6.140000     4.710000
# 25%       5.400000     1.490000    11.537500     8.677500     6.680000
# 50%       6.110000     1.760000    12.840000     9.545000     7.480000
# 75%       6.820000     2.010000    14.300000    10.670000     8.400000
# max       9.110000     3.160000    19.200000    14.540000    12.010000
#
#                LA           NV
# count  1212.00000  1212.000000
# mean      6.06250     5.119604
# std       0.80903     0.300297
# min       4.21000     4.020000
# 25%       5.47000     4.920000
# 50%       5.97000     5.160000
# 75%       6.58000     5.330000
# max       8.86000     5.930000

# %%
data.Labio.value_counts()
# Out:
# 0    616
# 1    596
# Name: Labio, dtype: int64

# %%
# esta selección..... que representa???
data.loc[np.logical_or(data["NV"] > 4.75, data["Labio"] == 1)]
# Out:
#       Lote  Individuo    AE    LE     AT     LT    AA    LA    NV Morfotipo  \
# 0       96          5  6.18  1.83  13.57  10.00  8.10  6.04  5.15        LU
# 1       96          5  6.16  1.83  13.66  10.08  8.16  6.13  5.12        LU
# 2       96          5  6.14  1.81  13.61  10.01  8.20  6.14  5.10        LU
# 3       96          5  6.18  1.82  13.85  10.07  8.16  6.14  5.09        LU
# 4       96          6  6.58  2.16  11.69   9.10  6.56  4.92  5.49        LU
# ...    ...        ...   ...   ...    ...    ...   ...   ...   ...       ...
# 1207   404          3  7.08  1.54  16.36  11.25  9.41  7.53  5.23        LU
# 1208   404          4  6.58  1.79  14.20  10.62  8.32  6.64  5.19        LB
# 1209   404          4  6.53  1.81  14.24  10.80  8.23  6.67  5.18        LB
# 1210   404          4  6.60  1.83  14.25  10.77  8.23  6.77  5.18        LB
# 1211   404          4  6.58  1.82  14.30  10.68  8.20  6.66  5.14        LB
#
#       Labio
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
# ...     ...
# 1207      1
# 1208      1
# 1209      1
# 1210      1
# 1211      1
#
# [1082 rows x 11 columns]

# %%
#Creamos un Filtro con NV > 4.75 y presencia de labio
data["Filtro_NV"] = np.where(np.logical_or(data["NV"] > 4.75, data["Labio"] == 1),True,False)

# %%
data.Filtro_NV.value_counts()
# Out:
# True     1082
# False     130
# Name: Filtro_NV, dtype: int64

# %%
#adultos con AT > 0.8 y presencia de Labio
data["Adulto_AT"] = np.where(np.logical_or(data["AT"] > 0.8, data["Labio"] == 1),True,False)

# %%
data.Adulto_AT.value_counts()
# Out:
# True    1212
# Name: Adulto_AT, dtype: int64

# %% [markdown]
# parece que son todos adultos los especímenes

# %% [markdown]
# ### Relación entre variables

# %%
sns.heatmap(data.iloc[:,2:-1].corr(), vmin = -1, vmax = 1, center = 0, cmap = "YlGnBu", annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=data,x_vars=['AE','LE','AT','LT','AA','LA','NV','Filtro_NV'],\
         y_vars=['AE','LE','AT','LT','AA','LA','NV','Filtro_NV'],hue='Morfotipo',plot_kws={'alpha': 0.5},aspect=1.5);
# Out:
# C:\Users\maela\anaconda3\envs\dhdsblend2021\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['AE','LE','AT','LT','AA','LA','NV'],\
         y_vars=['AE','LE','AT','LT','AA','LA','NV'],hue='Filtro_NV',plot_kws={'alpha': 0.5},aspect=1.5);

# %%
def distribution_plotter(data, label, bins="auto"):    
    plt.figure(figsize = (10,5))
    sns.set_style("white")    
    dist = sns.histplot(data, bins=bins, stat = "count", kde = False, 
                        line_kws = {'linewidth':5}, 
                        binwidth = 500)    
    dist.set_title('Distribucion ', fontsize = 16)
    plt.xticks(rotation=45, ha='right')

# %%
distribution_plotter(data["Morfotipo"],data["Morfotipo"].unique())

# %% [markdown]
# ### Recuento por Etiqueta

# %%
print(pd.value_counts(data["Morfotipo"], sort = True, normalize=True))
# Out:
# LU    0.858086
# LB    0.135314
# DU    0.006601
# Name: Morfotipo, dtype: float64

# %%
print(pd.value_counts(data["Filtro_NV"], sort = True, normalize=True))
# Out:
# True     0.892739
# False    0.107261
# Name: Filtro_NV, dtype: float64

# %% [markdown]
# ### Distribución de las observaciones

# %%
columns = data[["AE","LE","AT","LT","AA","LA","NV"]]
columns.hist()
# Out:
# array([[<AxesSubplot:title={'center':'AE'}>,
#         <AxesSubplot:title={'center':'LE'}>,
#         <AxesSubplot:title={'center':'AT'}>],
#        [<AxesSubplot:title={'center':'LT'}>,
#         <AxesSubplot:title={'center':'AA'}>,
#         <AxesSubplot:title={'center':'LA'}>],
#        [<AxesSubplot:title={'center':'NV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## Creamos columnas de relación entre variables

# %%
data["Ratio_LE_AE"] = data["LE"]/data["AE"]
data["Ratio_LT_AT"] = data["LT"]/data["AT"]
data["Ratio_LA_AA"] = data["LA"]/data["AA"]
data["Ratio_LE_LT"] = data["LE"]/data["LT"]
data["Ratio_AE_AT"] = data["AE"]/data["AT"]
data["Ratio_LA_LT"] = data["LA"]/data["LT"]
data["Ratio_AA_AT"] = data["AA"]/data["AT"]
data["Ratio_LE_LA"] = data["LE"]/data["LA"]
data["Ratio_AE_AA"] = data["AE"]/data["AA"]

#aux copy: 'Ratio_LE_AE','Ratio_LT_AT','Ratio_LA_AA','Ratio_LE_LT','Ratio_AE_AT','Ratio_LA_LT','Ratio_AA_AT','Ratio_LE_LA','Ratio_AE_AA'

# %%
data.head()
# Out:
#    Lote  Individuo    AE    LE     AT     LT    AA    LA    NV Morfotipo  ...  \
# 0    96          5  6.18  1.83  13.57  10.00  8.10  6.04  5.15        LU  ...
# 1    96          5  6.16  1.83  13.66  10.08  8.16  6.13  5.12        LU  ...
# 2    96          5  6.14  1.81  13.61  10.01  8.20  6.14  5.10        LU  ...
# 3    96          5  6.18  1.82  13.85  10.07  8.16  6.14  5.09        LU  ...
# 4    96          6  6.58  2.16  11.69   9.10  6.56  4.92  5.49        LU  ...
#
#    Adulto_AT  Ratio_LE_AE  Ratio_LT_AT  Ratio_LA_AA  Ratio_LE_LT  Ratio_AE_AT  \
# 0       True     0.296117     0.736920     0.745679     0.183000     0.455416
# 1       True     0.297078     0.737921     0.751225     0.181548     0.450952
# 2       True     0.294788     0.735489     0.748780     0.180819     0.451139
# 3       True     0.294498     0.727076     0.752451     0.180735     0.446209
# 4       True     0.328267     0.778443     0.750000     0.237363     0.562874
#
#    Ratio_LA_LT  Ratio_AA_AT  Ratio_LE_LA  Ratio_AE_AA
# 0     0.604000     0.596905     0.302980     0.762963
# 1     0.608135     0.597365     0.298532     0.754902
# 2     0.613387     0.602498     0.294788     0.748780
# 3     0.609732     0.589170     0.296417     0.757353
# 4     0.540659     0.561163     0.439024     1.003049
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Nueva visualización

# %%
sns.heatmap(data.corr().iloc[12:23,12:23], vmin = -1, vmax = 1, center = 0, cmap = "YlGnBu", annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=data,x_vars=['NV','Ratio_LE_AE','Ratio_LT_AT','Ratio_LA_AA','Ratio_LE_LT','Ratio_AE_AT','Ratio_LA_LT','Ratio_AA_AT','Ratio_LE_LA','Ratio_AE_AA','Filtro_NV'],\
         y_vars=['NV','Ratio_LE_AE','Ratio_LT_AT','Ratio_LA_AA','Ratio_LE_LT','Ratio_AE_AT','Ratio_LA_LT','Ratio_AA_AT','Ratio_LE_LA','Ratio_AE_AA','Filtro_NV'],\
             hue='Morfotipo',plot_kws={'alpha': 0.5},aspect=1.5, markers=['o','s','D'],palette='CMRmap', height=1.5);
# Out:
# C:\Users\maela\anaconda3\envs\dhdsblend2021\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Guía de Colores Pairplot: https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %% [markdown]
# ## Exportación dataset listo

# %%
data.to_csv(r'../data/conchillas_listo.csv', index = False, header=True)
